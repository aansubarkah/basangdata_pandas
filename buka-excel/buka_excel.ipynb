# %% [markdown]
# Kode pendamping tulisan https://basangdata.com/pandas-baca-tulis-file-excel

# %% [markdown]
# Sumber data:
# <ul>
#     <li><a href="https://community.tableau.com/docs/DOC-1236">https://community.tableau.com/docs/DOC-1236</a></li>
#     <li><a href="https://community.tableau.com/docs/DOC-10174">https://community.tableau.com/docs/DOC-10174</a></li>
# </ul>

# %% [markdown]
# # Install Paket dibutuhkan

# %%
#!pip install xlrd
#!pip install openpyxl
# Out:
# Processing /Users/aansubarkah/Library/Caches/pip/wheels/5b/c0/e7/e16d3916984addf40bd021fa98d1624cb24a9adc48da4e62b5/openpyxl-3.0.3-py2.py3-none-any.whl
# ...
#   Using cached jdcal-1.4.1-py2.py3-none-any.whl (9.5 kB)
# Processing /Users/aansubarkah/Library/Caches/pip/wheels/e2/bd/55/048b4fd505716c4c298f42ee02dffd9496bb6d212b266c7f31/et_xmlfile-1.0.1-py3-none-any.whl
# ...

# %% [markdown]
# # Mengimpor pandas

# %%
import pandas as pd

# %% [markdown]
# # Baca Excel

# %%
superstore = pd.read_excel('Sample - Superstore.xls')

# %%
superstore
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
returns = pd.read_excel('Sample - Superstore.xls', sheet_name='Returns')

# %%
returns
# Out:
#     Returned        Order ID
# 0        Yes  CA-2017-153822
# 1        Yes  CA-2017-129707
# 2        Yes  CA-2014-152345
# 3        Yes  CA-2015-156440
# 4        Yes  US-2017-155999
# ..       ...             ...
# 291      Yes  CA-2015-101910
# 292      Yes  CA-2017-156958
# 293      Yes  CA-2016-105585
# 294      Yes  CA-2016-148796
# 295      Yes  CA-2015-149636
#
# [296 rows x 2 columns]

# %% [markdown]
# central = pd.read_excel('Central_Superstore.xlsx')

# %%
central
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0       7981  CA-2011-103800 2013-01-03 2013-01-07  Standard Class
# 1        740  CA-2011-112326 2013-01-04 2013-01-08  Standard Class
# 2        741  CA-2011-112326 2013-01-04 2013-01-08  Standard Class
# 3        742  CA-2011-112326 2013-01-04 2013-01-08  Standard Class
# 4       7661  CA-2011-105417 2013-01-07 2013-01-12  Standard Class
# ...      ...             ...        ...        ...             ...
# 2318    6822  CA-2014-163860 2016-12-28 2017-01-01  Standard Class
# 2319    7485  CA-2014-135111 2016-12-28 2017-01-02  Standard Class
# 2320    7486  CA-2014-135111 2016-12-28 2017-01-02  Standard Class
# 2321    4240  CA-2014-158673 2016-12-29 2017-01-04  Standard Class
# 2322     646  CA-2014-126221 2016-12-30 2017-01-05  Standard Class
#
#      Customer ID       Customer Name      Segment        Country  \
# 0       DP-13000       Darren Powers     Consumer  United States
# ...

# %% [markdown]
# # Menambahkan Satu Kolom

# %%
superstore.head(1).T
# Out:
#                                                0
# Row ID                                         1
# Order ID                          CA-2016-152156
# Order Date                   2016-11-08 00:00:00
# Ship Date                    2016-11-11 00:00:00
# Ship Mode                           Second Class
# Customer ID                             CG-12520
# Customer Name                        Claire Gute
# Segment                                 Consumer
# Country                            United States
# City                                   Henderson
# State                                   Kentucky
# Postal Code                                42420
# Region                                     South
# Product ID                       FUR-BO-10001798
# Category                               Furniture
# Sub-Category                           Bookcases
# Product Name   Bush Somerset Collection Bookcase
# Sales                                     261.96
# ...

# %%
fullname = superstore['Customer Name'].str.split(' ', n = 1, expand = True)
superstore['First Customer Name'] = fullname[0]

# %%
superstore.head(1).T
# Out:
#                                                      0
# Row ID                                               1
# Order ID                                CA-2016-152156
# Order Date                         2016-11-08 00:00:00
# Ship Date                          2016-11-11 00:00:00
# Ship Mode                                 Second Class
# Customer ID                                   CG-12520
# Customer Name                              Claire Gute
# Segment                                       Consumer
# Country                                  United States
# City                                         Henderson
# State                                         Kentucky
# Postal Code                                      42420
# Region                                           South
# Product ID                             FUR-BO-10001798
# Category                                     Furniture
# Sub-Category                                 Bookcases
# ...

# %%
superstore[['Customer Name', 'First Customer Name']]
# Out:
#          Customer Name First Customer Name
# 0          Claire Gute              Claire
# 1          Claire Gute              Claire
# 2      Darrin Van Huff              Darrin
# 3       Sean O'Donnell                Sean
# 4       Sean O'Donnell                Sean
# ...                ...                 ...
# 9989  Tom Boeckenhauer                 Tom
# 9990       Dave Brooks                Dave
# 9991       Dave Brooks                Dave
# 9992       Dave Brooks                Dave
# 9993      Chris Cortes               Chris
#
# [9994 rows x 2 columns]

# %% [markdown]
# # Menyimpan Berkas Baru

# %%
superstore.to_excel('superstore.xlsx')
